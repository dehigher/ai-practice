# %% [markdown]
# <a href="https://colab.research.google.com/github/dehigher/ai-practice/blob/main/1_%E7%AC%AC%E4%B8%80%E4%B8%AA%E5%A4%A7%E8%AF%AD%E8%A8%80%E7%A8%8B%E5%BA%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install openai

# %%
# Please install OpenAI SDK first: `pip3 install openai`
import os
from openai import OpenAI

client = OpenAI(
    api_key= 'sk-3547bbf4b0da4f8eb5a99a049e2614d4',
    base_url="https://api.deepseek.com")

response = client.chat.completions.create(
    model="deepseek-chat",
    # system: 设置个性、表现、背景
    # user： 提问
    messages=[
        {"role": "system", "content": "你是一个AI助理"},
        {"role": "user", "content": "你好！你叫什么名字？"},
    ],
    stream=False,
    # max_tokens: 最大token数
    max_tokens = 10,
    # temperature: 随机性，0无随机，默认1，根据场景设置
    temperature = 1
)

for index, choice in enumerate(response.choices):
  print("index:{}, content:{}\n".format(index, choice.message.content))
# Out:
# index:0, content:你好！我是DeepSeek，由深度求

# %%
# !pip3 install tiktoken

# %%
import openai
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4")

chinese = """在未来还没有到来的时候，总要有人把它创造出来，那个人应该是我们。"""

# token
# token 是计算文本长度的基本单位，和单词并不是一一对应
# 同样的文本，不用模型消耗token不同
# 用于计费、限速
# tiktoken 工具包，用于分割token, 用于预估输入token数
# 英文更省钱，更友好
tokens = encoding.encode(chinese)

print(tokens)

num_of_tokens_in_chinese = len(encoding.encode(chinese))

print(f"chinese:{chinese} ; {num_of_tokens_in_chinese} tokens\n")
# Out:
# [19000, 39442, 37507, 98806, 81543, 28037, 37507, 9554, 13646, 20022, 247, 3922, 60843, 31634, 19361, 17792, 24326, 232, 8676, 225, 6701, 249, 67178, 20834, 37507, 3922, 45932, 96, 19483, 17792, 51611, 76982, 21043, 98739, 1811]
# chinese:在未来还没有到来的时候，总要有人把它创造出来，那个人应该是我们。 ; 35 tokens
